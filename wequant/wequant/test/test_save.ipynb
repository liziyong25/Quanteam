# %%
from wequant.wesu import QA_SU_save_etf_day, QA_SU_save_stock_day, QA_SU_save_future_day_all

QA_SU_save_etf_day(engine='tdx')
QA_SU_save_stock_day(engine='tdx')
QA_SU_save_future_day_all(engine='tdx')

# %%
import QUANTAXIS as QA
QA.QA_SU_save_stock_list(engine='tdx')
QA.QA_SU_save_index_list(engine='tdx')
QA.QA_SU_save_future_list(engine='tdx')
QA.QA_SU_save_etf_list(engine='tdx')
QA.QA_SU_save_stock_min(engine='tdx')
QA.QA_SU_save_future_min(engine='tdx')
QA.QA_SU_save_etf_min(engine='tdx')
QA.QA_SU_save_index_min(engine='tdx')
QA.QA_SU_save_stock_day(engine='tdx')
QA.QA_SU_save_future_day(engine='tdx')
QA.QA_SU_save_etf_day(engine='tdx')
QA.QA_SU_save_index_day(engine='tdx')
QA.QA_SU_save_stock_xdxr(engine='tdx')

# %%
from wequant.wesu import *
